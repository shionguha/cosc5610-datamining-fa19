# %% [markdown]
# Wayne Zachary, 1977, “An Information Flow Model for Conflict and Fission in Small Group”, Journal of Anthropological Research (cited ~3900 times according to Google Scholar)

# %%
import networkx as nx
import numpy as np
import itertools

import matplotlib.pyplot as plt
# %matplotlib inline
G = nx.karate_club_graph()

## #nodes: 34 and #edges: 78
print('#nodes:', len(G.nodes()), 'and', '#edges:', len(G.edges()))
# Out:
# #nodes: 34 and #edges: 78

# %%
node_to_degrees = sorted(dict(G.degree()).items(), key = lambda x: x[1], reverse = True)

## view the top 5,
node_to_degrees[:5]
# Out:
# [(33, 17), (0, 16), (32, 12), (2, 10), (1, 9)]

# %%
#initial plotting
plt.loglog(
    [ k for n, k in node_to_degrees ], 
    marker='.', linestyle='none')

plt.show()

#lets draw the network too
d = nx.draw_networkx(G)

# %%
## calculate degree centrality,
n_1 = float(len(node_to_degrees) - 1)
degree_centrality = [ (n, k, k/n_1) for n, k in node_to_degrees ]

## node, k, dc
sorted(degree_centrality, key = lambda x: x[2], reverse=True)
# Out:
# [(33, 17, 0.5151515151515151),
#  (0, 16, 0.48484848484848486),
#  (32, 12, 0.36363636363636365),
#  (2, 10, 0.30303030303030304),
#  (1, 9, 0.2727272727272727),
#  (3, 6, 0.18181818181818182),
#  (31, 6, 0.18181818181818182),
#  (8, 5, 0.15151515151515152),
#  (13, 5, 0.15151515151515152),
#  (23, 5, 0.15151515151515152),
#  (5, 4, 0.12121212121212122),
#  (6, 4, 0.12121212121212122),
#  (7, 4, 0.12121212121212122),
#  (27, 4, 0.12121212121212122),
#  (29, 4, 0.12121212121212122),
#  (30, 4, 0.12121212121212122),
#  (4, 3, 0.09090909090909091),
#  (10, 3, 0.09090909090909091),
#  (19, 3, 0.09090909090909091),
#  (24, 3, 0.09090909090909091),
#  (25, 3, 0.09090909090909091),
#  (28, 3, 0.09090909090909091),
#  (9, 2, 0.06060606060606061),
#  (12, 2, 0.06060606060606061),
#  (14, 2, 0.06060606060606061),
#  (15, 2, 0.06060606060606061),
#  (16, 2, 0.06060606060606061),
#  (17, 2, 0.06060606060606061),
#  (18, 2, 0.06060606060606061),
#  (20, 2, 0.06060606060606061),
# ...

# %%
#eigenvector centrality
#influence
eigenvector_centrality = nx.eigenvector_centrality(G)
eigenvector_centrality
# Out:
# {0: 0.35549072112370417,
#  1: 0.2659596047878132,
#  2: 0.31719241726880987,
#  3: 0.21117969364646638,
#  4: 0.07596887866870569,
#  5: 0.07948311304096012,
#  6: 0.07948311304096012,
#  7: 0.17095989227092295,
#  8: 0.2274043553316273,
#  9: 0.10267450362144723,
#  10: 0.07596887866870569,
#  11: 0.052855816844280215,
#  12: 0.08425472665295217,
#  13: 0.2264731120205241,
#  14: 0.10140364996835867,
#  15: 0.10140364996835867,
#  16: 0.023635566309504096,
#  17: 0.0923996985904049,
#  18: 0.10140364996835867,
#  19: 0.14791291834000603,
#  20: 0.10140364996835867,
#  21: 0.0923996985904049,
#  22: 0.10140364996835867,
#  23: 0.15011891153211476,
#  24: 0.057052325511109434,
#  25: 0.059206342354626885,
#  26: 0.07557961597057142,
#  27: 0.1334773858077505,
#  28: 0.13107796378977085,
#  29: 0.13496112225498727,
#  30: 0.17475863720466117,
#  31: 0.19103439403331252,
#  32: 0.30864374859179716,
#  33: 0.3733625389682142}

# %%
#closeness centrality
#shortest number of "hops" to get anywhere. positional centrality
closeness_centrality = nx.closeness_centrality(G)
closeness_centrality
# Out:
# {0: 0.5689655172413793,
#  1: 0.4852941176470588,
#  2: 0.559322033898305,
#  3: 0.4647887323943662,
#  4: 0.3793103448275862,
#  5: 0.38372093023255816,
#  6: 0.38372093023255816,
#  7: 0.44,
#  8: 0.515625,
#  9: 0.4342105263157895,
#  10: 0.3793103448275862,
#  11: 0.36666666666666664,
#  12: 0.3707865168539326,
#  13: 0.515625,
#  14: 0.3707865168539326,
#  15: 0.3707865168539326,
#  16: 0.28448275862068967,
#  17: 0.375,
#  18: 0.3707865168539326,
#  19: 0.5,
#  20: 0.3707865168539326,
#  21: 0.375,
#  22: 0.3707865168539326,
#  23: 0.39285714285714285,
#  24: 0.375,
#  25: 0.375,
#  26: 0.3626373626373626,
#  27: 0.4583333333333333,
#  28: 0.4520547945205479,
#  29: 0.38372093023255816,
#  30: 0.4583333333333333,
#  31: 0.5409836065573771,
#  32: 0.515625,
#  33: 0.55}

# %%
#betweenness centrality
#information broker
betweenness_centrality = nx.betweenness_centrality(G)
betweenness_centrality
# Out:
# {0: 0.43763528138528146,
#  1: 0.053936688311688304,
#  2: 0.14365680615680618,
#  3: 0.011909271284271283,
#  4: 0.0006313131313131313,
#  5: 0.02998737373737374,
#  6: 0.029987373737373736,
#  7: 0.0,
#  8: 0.05592682780182781,
#  9: 0.0008477633477633478,
#  10: 0.0006313131313131313,
#  11: 0.0,
#  12: 0.0,
#  13: 0.04586339586339586,
#  14: 0.0,
#  15: 0.0,
#  16: 0.0,
#  17: 0.0,
#  18: 0.0,
#  19: 0.03247504810004811,
#  20: 0.0,
#  21: 0.0,
#  22: 0.0,
#  23: 0.017613636363636363,
#  24: 0.0022095959595959595,
#  25: 0.0038404882154882154,
#  26: 0.0,
#  27: 0.02233345358345358,
#  28: 0.0017947330447330447,
#  29: 0.0029220779220779218,
#  30: 0.014411976911976909,
#  31: 0.13827561327561325,
#  32: 0.145247113997114,
#  33: 0.30407497594997596}

# %%
d = nx.draw_networkx(G)
